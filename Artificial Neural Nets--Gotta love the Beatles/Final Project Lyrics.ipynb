# %%
import glob
import pickle
import numpy as np
import os
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.layers import LSTM
from keras.layers import Activation
from keras.layers import BatchNormalization as BatchNorm
from keras.utils import np_utils
from keras.callbacks import ModelCheckpoint
import tensorflow as tf
from textgenrnn import textgenrnn
# !pip install tensorflow==1.14
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
##Importing data
data = '/content/drive/My Drive/Artificial Neural Nets--Gotta love the Beatles/TheBeatlesLyrics.txt'

# %%
# network that trains at the word level
textgen = textgenrnn(name = "word level model")
textgen.reset()

textgen.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=True,
                        max_length = 8,
                        max_gen_length = 50,
                        word_level = True,
                        rnn_size=128,
                        num_epochs=50)
# Out:
# Training new model w/ 2-layer, 128-cell Bidirectional LSTMs
# Training on 48,646 word sequences.
# Epoch 1/50
# 380/380 [==============================] - 70s 185ms/step - loss: 4.4092
# ####################
# Temperature: 0.2
# ####################
#
#  i ’ m in the middle of the end
# i ’ m a feeling man ,
# i ’ m going to be your mind
# i ’ m a m a star
# i ’ m going to know i ’ m going to be
# i
#
# of things i ’ m in the sleeping
# i ’ m a m in love with you
# i ’ m gonna have a change
# i ’ m going to be
# i ’ m a feeling
# i ’ m a m in your mind
# i
#
#
#  i ’ m in the middle of the end
# i ’ m in the taxman
# i ’ m a doing to dance with you
# i ’ m in the middle of the end
# i ’ m in the middle of things i ’ m in
#
# ####################
# Temperature: 0.5
# ####################
#
#  we ’ re going to crucify me
# i ’ ve got to know my friend
# ‘ cause i ’ ve been a time
# i ’ m in her away
# i ’ m going to get again
# that ’ s what i want to be
#
# ...

# %%
textgen.generate(temperature = .4)
# Out:
#  i said that was before a bad like a man
# that boy her not a lot to shine
# , the world you know is a yeah .
# i ’ ve got a feeling , a feeling deep inside
# oh yeah , oh yeah .
# ev ’ rybody had a good year ,
# ev ’ rybody let their hair down ,
# ev ’ rybody pulled their socks up ,
# ev ’ rybody put their foot down .
# oh yeah , oh yeah .
# [ oh my soul . . . so odd . ]
# i ’ ve just seen a face ,
# i can ’ t forget the time or place
# where we just meet .
# she ’ s just the girl for me
# and want all the world to see
# we ’ ve met , mmm - mmm - mmm - m ’ mmm - mmm .
# had it been another day
# i might have looked the other way
# and i ’ d have never been aware .
# but as it is i ’ ll dream of her
# tonight , di - di - di - di ’ n ’ di .
# falling , yes i am falling ,
# and she keeps calling
# me back again .
# i have never known
# the like of this , i ’ ve been alone
# and i have missed things
# and kept out of sight
# but other girls were never quite
# ...

# %%
# bidirectional network that trains at the character level
from textgenrnn import textgenrnn
textgen2 = textgenrnn(name = "character level model")
textgen2.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=False,
                        max_length = 40,
                        max_gen_length = 150,
                        word_level = True,
                        rnn_size=128,
                        batch_size=256,
                        num_epochs=40)
# Out:
# Streaming output truncated to the last 5000 lines.
# we ’ re going to know
# that ’ s going to crucify me .
# the way going to take a little girl
# you ’ re going to crucify me me .
# you ’ re going to lose that a little money can ’ t dead
# you can make a chance that can be .
# you don ’ t run and hide , the one can ’ t hide .
# after the honey don ’ t mind
# i don ’ t know why , you ’ re trav ’ ling on the one after after 9
# after 909
# i said move over once , i ’ m trav ’ ling on the one after 909
# i said move over honey i ’ m travelling on
#
# cause i used to leave her
# and i would rather do
# if i love her with a lot
# but i can ' t forget her ,
# and then i gotta love her ,
# i love her away from me .
# i ' ve got a love her and i ' ve got a new
# but i ' ve got no time ,
# i ' ve got no time for i ' ve got a big surprise ,
# oh ho , oh ho , oh , yeah .
# i ' ve got a chip my love and things to do
# i ' ll make a new and i want to hold your hand ,
# ...

# %%
textgen2.generate(temperature = .6)
# Out:
# coming home again , to be the end ,
# and i write this letter ,
# send my love to you .
# i could be true , i wanna be your lover .
# i wanna be your man , i ’ m telling you .
# i know i can tell you ,
# your life i ’ ll apologize ,
# you can ’ t do it , yeah .
# yes , it ’ s true ,
# you can you don ’ t need me .
# love you , i need you , my love i ’ m always ,
# oh , yeah , i ’ m gonna
# love with you .
# treasure these few words ‘ till we ’ re together ,
# keep all my love forever ,
# p s . . .
# you , you , you , you as i write this letter ,
# ( oh oh yeah )
# i give her all my love was i ’ ve got a bad .
# oh , yeah , i ’ m with a love with you
# i love you ’ d hate to tell her .
# i think you ’ d say that i love ,
# don ’ t you know that isn ’ t you see ,
# i don ’ t stand in the eye ,
# i ’ ll never known to tell her you and me
# and i ’ ll go her .
# she ’ s one a girl ,
# i can ’ t see that i still
# i know that she ’ s lonely
# don ’ t know why should i think of mind
# ...

# %%
# bidirectional network that trains at the word level with a little dropout
from textgenrnn import textgenrnn
textgen3 = textgenrnn(name = "word level model with drop")


textgen3.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=True,
                        max_length = 8,
                        max_gen_length = 50,
                        word_level = True,
                        rnn_size=128,
                        num_epochs=40,
                        dropout=4)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
textgen3.generate(temperature = .6)
# Out:
# and listen to the music
# i can only waiting for you all right .
# if i saw you our love you ,
# i ’ ve got so hold in a girl
# i want to tell you
# i feel hung up but i don ' t know why ,
# i don ’ t mind
# i could wait forever , i ' ve got time
# sometimes i wish i knew you well ,
# then i could speak my mind and tell you
# maybe you ' d understand
# i want to tell you
# i feel hung up but i don ' t know why ,
# i don ’ t mind
# i could wait forever , i ' ve got time
# sometimes i wish i knew you well ,
# then i could speak my mind and tell you
# maybe you ' d understand
# i want to tell you
# i want to tell you
# my head is filled with things to say
# when you ' re here
# all those words , they seem to slip away
# when i get near you ,
# the games begin to drag me down
# it ' s all right
# i ' ll make you maybe next time around
# but if i seem to act unkind
# it ' s only me , it ’ s not my mind
# that is confusing things .
# i want to tell you
# ...

# %%
#character level model with a little dropout
from textgenrnn import textgenrnn
textgen4 = textgenrnn(name = "character level model with drop")
textgen4.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=False,
                        max_length = 40,
                        max_gen_length = 150,
                        word_level = True,
                        rnn_size=128,
                        batch_size=256,
                        num_epochs=40,
                        drop=20)
# Out:
# Streaming output truncated to the last 5000 lines.
# you ’ re going to lose that girl ,
# you ’ re going to lose that girl ,
# you ’ re going to lose that girl ,
# you ’ re going to lose that that ’ d to be late .
# and you ’ re going lose that girl ,
# i got something
#
# ####################
# Temperature: 1.0
# ####################
# my clothes .
# hewr stop and the low he well shoulder to honey
# you know it my war
# ran judge maggie her wife mae her her home
# and i got to tell her that she ’ s gonna tear her something ,
# caught postcards on
# talking in back again
# to love all the quite that ’ s blind ,
# what you ’ re nowhere , to be easy
# for you don ’ t take out ,
# it ’ s got a chance that we ’ d like .
# i can ’ t you think it ’ s something
# think of i love you ’ re tryin ’ ’ to make me
# a ‘ cause i ’ m going to you
# some too too much
# you ’ re going to prove , you
# you don
#
# bei uptown
# du glücklich und
# hab
# hab
# buy sie liebt . dich dich dich dich
# ...

# %%
textgen4.generate(temperature = .5)
# Out:
# thought he wants you all the queen .
# he ’ s all the world all
# you can ’ t know that i ’ m changing faster than to see
# you know i need is love
# you ’ ll never know that ’ m true
# ( when i ’ m coming home you ’ ll be mine , yeah .
# i ’ ve been away
# you don ’ t know my mind
# i ’ ve tried to to leave
# your heart , ‘ cause i ’ t stand it up ,
# oh ,
# i wouldn ’ t mind .
# if you don ’ t mind ,
# i will where you ’ ll always ,
# ‘ cause you told me that ’ s true
# ‘ cause i like you too ,
# oh , no - oh
# you ’ ve ever had a drag me down
# well , i know that ’ s so oh
# oh , oh , i ’ ve got a feeling .
# oh please , oh please ,
# i ’ ve got no feeling on , oh no .
# oh no , no one time ,
# i ’ ve got no time for trivialities ,
# you ’ ve got a time at me cry
# baby i ’ ve been alone
# i said i ’ ve been alone
# and i love her back again
# wait till i i have been alone
# wait till i i ’ m back
# where you can see
# i ’ m so alone and the time to know
# ...

# %%
#bidirectional word level model with dropout
from textgenrnn import textgenrnn
textgen5 = textgenrnn(name = "word level model with extra drop")


textgen5.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=True,
                        max_length = 8,
                        max_gen_length = 50,
                        word_level = True,
                        rnn_size=128,
                        num_epochs=40,
                        train_size = .8,
                        dropout=10000)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
textgen5.generate(temperature = 1)
# Out:
# for .
# the word and you know
# the way the people that she really was born
# she don ' t know what it ' s like to be ,
# there ' s no fun tonight that is all .
# you ’ ll be is full of life ,
# if you have my life i can have but i feel blue ,
# and lonely .
# it doesn ' t really matter what ' s made .
# what do is to be right
# when i know that she ’ s lying ,
# there ’ ll remember all the time to see
# we ’ ve met , mmm - mmm - mmm - m ’ mmm - mmm .
# had it been another girl ,
# i still always be so much ,
# i love you more , i hear me in time
# well you can me fine
# i will you still need me ,
# any old time you use it
# it ’ s gotta be rock roll music
# if you wanna dance with me
# if you wanna dance with me
# if you wanna dance with me
# hold me
# since i ’ ve been gonna say that i misery
# i ’ m one .
# lonely , yes i am falling ,
# and she keeps calling
# me back again .
# falling , yes i am falling ,
# and she keeps calling
# me back again .
# ...

# %%
#bidirectional character level model with dropout
from textgenrnn import textgenrnn
textgen6 = textgenrnn(name = "character level model with extra drop")
textgen6.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=False,
                        max_length = 40,
                        max_gen_length = 150,
                        word_level = False,
                        rnn_size=128,
                        batch_size=256,
                        num_epochs=40,
                        drop=50000)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-19af33e756fc> in <module>()
#       1 from textgenrnn import textgenrnn
# ----> 2 textgen6 = textgenrnn(name = "character level model with extra drop")
#       3 textgen6.train_from_largetext_file(data,
#       4                         new_model=True,
#       5                         rnn_bidirectional=False,
#
# /usr/local/lib/python3.6/dist-packages/textgenrnn/textgenrnn.py in __init__(self, weights_path, vocab_path, config_path, name)
#      65         self.model = textgenrnn_model(self.num_classes,
#      66                                       cfg=self.config,
# ---> 67                                       weights_path=weights_path)
#      68         self.indices_char = dict((self.vocab[c], c) for c in self.vocab)
#      69
#
# ...

# %%
textgen6.generate(temperature = .3, max_gen_length=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-1dcddbe6b790> in <module>()
# ----> 1 textgen6.generate(temperature = .3, max_gen_length=1000)
#
# NameError: name 'textgen6' is not defined

# %%
#bidirectional word level model with some dropout and fewer predictive words
from textgenrnn import textgenrnn
textgen7 = textgenrnn(name = "word level model with fewer words")

textgen7.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=True,
                        max_length = 4,
                        max_gen_length = 50,
                        word_level = True,
                        dropout = 5000,
                        train_size=.9,
                        rnn_size=128,
                        num_epochs=50)
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
textgen7.generate(temperature = .5)
# Out:
# be your man .
# i wanna be your man .
# tell me why you cried , and why you lied to me .
# if there ' s anything i can do ,
# just call on me and i ' ll send it along
# with love from me to you .
# i ’ ve got a feeling , a feeling i can ’ t forget the time or place
# where we just meet .
# she ’ s got a back beat , you can ’ t do that .
# well , if you don ’ t want to kiss you , yeah .
# chains , my baby ' s got me locked up in chains ,
# and they ain ' t the kind that you can see .
# whoa , love me do .
# love you ev ' ry day ,
# and i ' ll send all my loving to you .
# i ’ ll never do you no harm
# believe me when i tell you
# i feel hung up but i don ' t know why you say goodbye , i say hello
# ( hello goodbye hello goodbye ) hello hello
# ( hello goodbye ) i don ' t know why you say goodbye , i say hello
# hello hello
# i don ' t want ,
# for i have got another girl . another girl .
# who will love me till the end .
# through thick and thin
# she will always be my friend .
# ...

# %%
#bidirectional word level model with some dropout and even fewer predicitive words

from textgenrnn import textgenrnn
textgen8 = textgenrnn(name = "word level model with even fewer words")


textgen8.train_from_largetext_file(data,
                        new_model=True,
                        rnn_bidirectional=True,
                        max_length = 2,
                        max_gen_length = 50,
                        word_level = True,
                        dropout = 5000,
                        train_size=.9,
                        rnn_size=128,
                        num_epochs=100)
# Out:
# Streaming output truncated to the last 5000 lines.
# ####################
# because the sky with diamonds .
# i ’ m so tired i don ' t let me down . )
# well you can ’ t be long please don ' t let me down . )
# i ’ m so tired i don ' t be long
#
# i ' m feeling blue and lonely ,
# i ' m down ( i ' m down ( i ' m in love with you .
# i ' m feeling blue and lonely
# and i ' ll be free .
# i ' m feeling blue and
#
# i ' m down ( i ' m crying , i ' m in love with you
# and i ' m in love with her and i ' m in love with her and i ' m down ( i ' m crying , i ' m down (
#
# ####################
# Temperature: 0.5
# ####################
#
#  but she don ’ t be long or i am the walrus , goo goo g ' goo goo g ' joob g ' goo goo g ' goo goo g ' goo goo g ' goo goo g ' joob .
# i don ' t matter what
#
# because the world is round .
# i don ' t come .
# i ’ m gone
# and i say or time of day it is .
# i ' m in love with me
# she ’ s lonely hearts club band
# we ’ re coming
#
#
# ...

# %%
textgen8.generate(temperature = .5)
# Out:
# in the clouds ,
# i ' ll never hurt em
# she ' s something there
# i ' m down ( i ' m really down )
# how could i ever have lost you
# i ’ m so tired my mind
# in the sky with diamonds .
# i ' m in love with you
# you know you know it ain ’ t be long please don ' t be long
# please , love me do .
# i ’ m the taxman
# and i ' m in love with you
# and in the morning
# lift my head ,
# i wanna be your man .
# don ' t be long - don ' t be long please don ' t you please , love me do .
# i ’ ll be good like i ’ m coming back home
# i ' m gonna be a show you what your loving man can you hear me ,
# you won ’ t stand the pain
# and want all the world is treating me bad .
# i know i ' m in love with you .
# i ’ ve been alone and there ’ s got a whole lot of things to tell you ,
# i ' m in love with you
# i ’ m going to strawberry fields .
# i ' m gonna let you down , don ' t let me down .
# oh , komm doch ,
# and though i lose a friend ,
# ...
